# %% [markdown]
# <a href="https://colab.research.google.com/github/happyCodingSusan/hand_object_detector/blob/master/hod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/happyCodingSusan/hand_object_detector.git
# !apt install python3.6 python-pip
# !pip install pytorch=1.0.1 torchvision cudatoolkit=10.0 -c pytorch
# !pip install -r requirements.txt
import os
os.chdir('hand_object_detector')
os.chdir('lib')
# !python setup.py build develop
# Out:
# fatal: destination path 'hand_object_detector' already exists and is not an empty directory.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3.6 is already the newest version (3.6.9-1~18.04ubuntu1.1).
# python-pip is already the newest version (9.0.1-2.3~ubuntu1.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'pytorch'
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.6
# creating build/lib.linux-x86_64-3.6/datasets
# copying datasets/__init__.py -> build/lib.linux-x86_64-3.6/datasets
# copying datasets/coco.py -> build/lib.linux-x86_64-3.6/datasets
# ...

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'hand_object_detector', 'sample_data']

# %%
os.chdir('hand_object_detector')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-78e5710dd74e> in <module>()
# ----> 1 os.chdir('hand_object_detector')
#       2 os.listdir()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hand_object_detector'

# %%
os.listdir()
# Out:
# ['trainval_net.py',
#  'cfgs',
#  '.git',
#  'demo.py',
#  'test.md',
#  'requirements.txt',
#  '_init_paths.py',
#  '.gitignore',
#  'lib',
#  'README.md',
#  'test_net.py',
#  'assets']

# %%
os.getcwd()
# Out:
# '/content/hand_object_detector/hand_object_detector'

# %%
os.getcwd()
# Out:
# '/content/hand_object_detector'

# %%
# !wget https://drive.google.com/file/d/1H2tWsZkS7tDF8q1-jdjx6V9XrK25EDbE faster_rcnn_1_8_132028.pth
# Out:
# --2020-08-16 23:26:43--  https://drive.google.com/file/d/1H2tWsZkS7tDF8q1-jdjx6V9XrK25EDbE
# Resolving drive.google.com (drive.google.com)... 74.125.195.102, 74.125.195.113, 74.125.195.101, ...
# Connecting to drive.google.com (drive.google.com)|74.125.195.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://drive.google.com/file/d/1H2tWsZkS7tDF8q1-jdjx6V9XrK25EDbE/ [following]
# --2020-08-16 23:26:43--  https://drive.google.com/file/d/1H2tWsZkS7tDF8q1-jdjx6V9XrK25EDbE/
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://drive.google.com/file/d/1H2tWsZkS7tDF8q1-jdjx6V9XrK25EDbE/edit [following]
# --2020-08-16 23:26:43--  https://drive.google.com/file/d/1H2tWsZkS7tDF8q1-jdjx6V9XrK25EDbE/edit
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# ...

# %%
# !mkdir models
os.chdir('models')
# !mkdir res101_handobj_100K
os.chdir('res101_handobj_100K')
# !mkdir pascal_voc
os.chdir('..')
os.chdir('..')
os.getcwd()

# %%
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-e350d6f0-619b-41b6-a0a9-70b687c75005" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e350d6f0-619b-41b6-a0a9-70b687c75005">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving faster_rcnn_1_8_89999.pth to faster_rcnn_1_8_89999.pth

# %%
# !mv faster_rcnn_1_8_89999 models/res101_handobj_100K/pascal_voc
